# %%
# %pylab inline
import pyemma.coordinates as coor
import pyemma.msm as msm
import pyemma.plots as mplt
import pandas as pd
import mdtraj as md
import scipy as sp
from mpl_toolkits.mplot3d import Axes3D
from MDAnalysis.lib.distances import calc_angles
from MDAnalysis.lib.distances import calc_bonds
from glob import glob
import numpy as np
import pyemma.coordinates as coor
import seaborn as sns
import multiprocessing
import pickle

import warnings

warnings.filterwarnings("ignore")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r_o = pickle.load(open('/home/dldx/R-H/code/classification/ML/plot/fig6/D/end_r_o_sasa.pkl','rb'))
h_o = pickle.load(open('/home/dldx/R-H/code/classification/ML/plot/fig6/D/end_h_o_sasa.pkl','rb'))
r_c = pickle.load(open('/home/dldx/R-H/code/classification/ML/plot/fig6/D/end_r_c_sasa.pkl','rb'))
h_c = pickle.load(open('/home/dldx/R-H/code/classification/ML/plot/fig6/D/end_h_c_sasa.pkl','rb'))

# %%
# R_open
colors = iter(cm.Reds(np.linspace(0.39, 1, 10)))
figure(figsize=(10,6))
for i in range(0,10):
    plot(r_o[i], color = next(colors),linewidth=0.36)
font={'size':15,
     'weight':'bold',}
legend(["r1","r2","r3","r4","r5",
        "r6","r7","r8","r9","r10"],
        loc="upper center",ncol=5,prop=font)
plt.text(100,324, '%s'%('A'), weight='bold',fontsize=15)
xlim(0,10100)
xticks(range(0,10100,1000),range(0,101,10),weight='bold',fontsize=15)
xlabel('Time (ns)', weight='bold',fontsize=16)
ylim(220,330)
yticks([220,240,260,280,300,320],weight='bold',fontsize=15)
ylabel('SASA (nm\u00B2)',weight='bold',fontsize=16)
plt.savefig("/home/dldx/R-H/code/supplementary/S4/R_open_sasa.jpg",dpi=900)

# %%
# H_open
colors = iter(cm.Blues(np.linspace(0.39, 1, 10)))
figure(figsize=(10,6))
for i in range(0,10):
    plot(h_o[i], color = next(colors),linewidth=0.36)
font={'size':15,
     'weight':'bold',}
legend(["r1","r2","r3","r4","r5",
        "r6","r7","r8","r9","r10"],
        loc="upper center",ncol=5,prop=font)
plt.text(100,324, '%s'%('B'), weight='bold',fontsize=15)
xlim(0,10100)
xticks(range(0,10100,1000),range(0,101,10),weight='bold',fontsize=15)
xlabel('Time (ns)', weight='bold',fontsize=16)
ylim(220,330)
yticks([220,240,260,280,300,320],weight='bold',fontsize=15)
ylabel('SASA (nm\u00B2)',weight='bold',fontsize=16)
plt.savefig("/home/dldx/R-H/code/supplementary/S4/H_open_sasa.jpg",dpi=900)

# %%
# R_close
colors = iter(cm.Reds(np.linspace(0.39, 1, 10)))
figure(figsize=(10,6))
for i in range(0,10):
    plot(r_c[i], color = next(colors),linewidth=0.36)
font={'size':15,
     'weight':'bold',}
legend(["r1","r2","r3","r4","r5",
        "r6","r7","r8","r9","r10"],
        loc="upper center",ncol=5,prop=font)
plt.text(100,324, '%s'%('C'), weight='bold',fontsize=15)
xlim(0,10100)
xticks(range(0,10100,1000),range(0,101,10),weight='bold',fontsize=15)
xlabel('Time (ns)', weight='bold',fontsize=16)
ylim(220,330)
yticks([220,240,260,280,300,320],weight='bold',fontsize=15)
ylabel('SASA (nm\u00B2)',weight='bold',fontsize=16)
plt.savefig("/home/dldx/R-H/code/supplementary/S4/R_close_sasa.jpg",dpi=900)

# %%
# H_close
colors = iter(cm.Blues(np.linspace(0.39, 1, 10)))
figure(figsize=(10,6))
for i in range(0,10):
    plot(h_c[i], color = next(colors),linewidth=0.36)
font={'size':15,
     'weight':'bold',}
legend(["r1","r2","r3","r4","r5",
        "r6","r7","r8","r9","r10"],
        loc="upper center",ncol=5,prop=font)
plt.text(100,324, '%s'%('D'), weight='bold',fontsize=15)
xlim(0,10100)
xticks(range(0,10100,1000),range(0,101,10),weight='bold',fontsize=15)
xlabel('Time (ns)', weight='bold',fontsize=16)
ylim(220,330)
yticks([220,240,260,280,300,320],weight='bold',fontsize=15)
ylabel('SASA (nm\u00B2)',weight='bold',fontsize=16)
plt.savefig("/home/dldx/R-H/code/supplementary/S4/H_close_sasa.jpg",dpi=900)
