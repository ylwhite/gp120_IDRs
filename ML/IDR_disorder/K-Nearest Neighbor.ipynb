# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings

warnings.filterwarnings("ignore")

# %%
disorder_R_H = pickle.load(open('/home/dldx/R-H/code/classification/ML/data/disorder/avg_R-H_all_dsiorder.pkl','rb'))

data1 = pd.read_csv('/home/dldx/R-H/code/classification/ML/data/disorder/MSA_disorder_R_H.csv')
input_lable = np.array(data1.Tier)

# %%
all_21_IDR_disorder = []
for position in range(21):
    one_IDR = []
    R_IDR = [i[position] for i in disorder_R_H[0]]
    H_IDR = [i[position] for i in disorder_R_H[1]]
 
    # 转化为二维数组
    for i in range(72):
        test =[]
        test.append(R_IDR[i])
        one_IDR.append(test)
    for i in range(107):
        test =[]
        test.append(H_IDR[i])
        one_IDR.append(test)

    # 所有IDR的平均disorder值添加到一个数组
    all_21_IDR_disorder.append(one_IDR)

# %%
disorder_R_H[0][65][15]
# Out:
# 0.03288253745995458

# %%
# 重新跑关于IDR16由数据更改的情况

# 评估结果
all_21_IDR_length_evaluate = []
# 设置超参数  
param_dict = {"n_neighbors": np.arange(1, 11), "weights":["uniform","distance"]}

# 21个IDR区域分别进行分类
one_evaluate = []
for r in range(31):
    one_random_state = []
    # 划分训练集和测试集
    Xtrain,Xtest,Ytrain,Ytest = train_test_split(all_21_IDR_disorder[15],input_lable,train_size=0.8,random_state = r)
    # build model
    model = KNeighborsClassifier()
    # 将模型加入超参数网格搜索和交叉验证     
    model = GridSearchCV(model, param_grid=param_dict, cv=5)
    # model train
    model = model.fit(Xtrain,Ytrain)
    # 最优的模型参数
    params = model.best_params_ 
    # 模型评估
    predict = model.predict(Xtest)
    cm = confusion_matrix(Ytest,predict)
    tn, tp, fn, fp = cm[0][0], cm[1][1], cm[1][0], cm[0][1]
    n = tp + fp + tn + fn
    accuracy = (tp + tn)/n 
    mcc = ((tp*tn) - (fp*fn))/np.sqrt((tp+fp)*(tn+fn)*(tp+fn)*(tn+fp))
    sens = tp/(tp + fn) * 100 if tp + fp != 0 else 0
    spec = tn/(tn + fp) * 100 if tn + fn != 0 else 0
    one_random_state.append(accuracy)
    one_random_state.append(mcc)
    one_random_state.append(sens)
    one_random_state.append(spec)
    one_evaluate.append(one_random_state)

    print("数据集划分 random_state：" + str(r)  + "时，")
    print("Evaluate：")
    print("最优的模型参数是：" + str(params))
    print("  accuracy : " + str(accuracy))
    print("  mcc : " + str(mcc))
    print("  sens : " + str(sens))
    print("  spec : " + str(spec)) 
    print("============================")

all_21_IDR_length_evaluate.append(one_evaluate)
print("以上为IDR__" + str(15 + 1) + "时，evaluation")
# Out:
# 数据集划分 random_state：0时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 10, 'weights': 'uniform'}
#   accuracy : 0.6388888888888888
#   mcc : 0.3585685828003181
#   sens : 26.666666666666668
#   spec : 90.47619047619048
# ============================
# 数据集划分 random_state：1时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.3504383220252312
#   sens : 58.82352941176471
#   spec : 73.68421052631578
# ============================
# 数据集划分 random_state：2时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.5555555555555556
#   mcc : 0.2041241452319315
#   sens : 40.0
#   spec : 75.0
# ============================
# 数据集划分 random_state：3时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 8, 'weights': 'uniform'}
#   accuracy : 0.6388888888888888
#   mcc : 0.286924556381635
#   sens : 50.0
#   spec : 75.0
# ============================
# 数据集划分 random_state：4时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 10, 'weights': 'uniform'}
#   accuracy : 0.75
#   mcc : 0.41576620649295015
#   sens : 54.54545454545454
#   spec : 84.0
# ============================
# 数据集划分 random_state：5时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 5, 'weights': 'uniform'}
#   accuracy : 0.5277777777777778
#   mcc : 0.0812566369992173
#   sens : 42.10526315789473
#   spec : 64.70588235294117
# ============================
# 数据集划分 random_state：6时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.30151134457776363
#   sens : 71.42857142857143
#   spec : 63.63636363636363
# ============================
# 数据集划分 random_state：7时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'uniform'}
#   accuracy : 0.6944444444444444
#   mcc : 0.19241827716833385
#   sens : 50.0
#   spec : 75.0
# ============================
# 数据集划分 random_state：8时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 8, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.3892494720807615
#   sens : 28.57142857142857
#   spec : 90.9090909090909
# ============================
# 数据集划分 random_state：9时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 8, 'weights': 'uniform'}
#   accuracy : 0.5555555555555556
#   mcc : 0.18961876139204215
#   sens : 36.84210526315789
#   spec : 76.47058823529412
# ============================
# 数据集划分 random_state：10时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'uniform'}
#   accuracy : 0.6944444444444444
#   mcc : 0.45534475178177536
#   sens : 50.0
#   spec : 85.0
# ============================
# 数据集划分 random_state：11时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.6013377943029549
#   sens : 38.88888888888889
#   spec : 94.44444444444444
# ============================
# 数据集划分 random_state：12时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.42129071128957707
#   sens : 47.05882352941176
#   spec : 84.21052631578947
# ============================
# 数据集划分 random_state：13时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'uniform'}
#   accuracy : 0.6111111111111112
#   mcc : 0.16116459280507606
#   sens : 28.57142857142857
#   spec : 81.81818181818183
# ============================
# 数据集划分 random_state：14时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'uniform'}
#   accuracy : 0.6388888888888888
#   mcc : 0.3585685828003181
#   sens : 26.666666666666668
#   spec : 90.47619047619048
# ============================
# 数据集划分 random_state：15时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'uniform'}
#   accuracy : 0.6944444444444444
#   mcc : 0.3117532399905863
#   sens : 50.0
#   spec : 79.16666666666666
# ============================
# 数据集划分 random_state：16时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'uniform'}
#   accuracy : 0.7222222222222222
#   mcc : 0.3965923098747467
#   sens : 84.61538461538461
#   spec : 65.21739130434783
# ============================
# 数据集划分 random_state：17时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.20016019225635892
#   sens : 50.0
#   spec : 73.07692307692307
# ============================
# 数据集划分 random_state：18时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.5833333333333334
#   mcc : 0.2566132111487139
#   sens : 50.0
#   spec : 71.42857142857143
# ============================
# 数据集划分 random_state：19时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'uniform'}
#   accuracy : 0.6388888888888888
#   mcc : 0.2222771122371935
#   sens : 53.84615384615385
#   spec : 69.56521739130434
# ============================
# 数据集划分 random_state：20时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'uniform'}
#   accuracy : 0.75
#   mcc : 0.427617987059879
#   sens : 75.0
#   spec : 75.0
# ============================
# 数据集划分 random_state：21时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 10, 'weights': 'uniform'}
#   accuracy : 0.5
#   mcc : 0.0
#   sens : 22.22222222222222
#   spec : 77.77777777777779
# ============================
# 数据集划分 random_state：22时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 10, 'weights': 'uniform'}
#   accuracy : 0.7222222222222222
#   mcc : 0.34545454545454546
#   sens : 54.54545454545454
#   spec : 80.0
# ============================
# 数据集划分 random_state：23时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.7222222222222222
#   mcc : 0.4351941398892446
#   sens : 57.14285714285714
#   spec : 81.81818181818183
# ============================
# 数据集划分 random_state：24时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 8, 'weights': 'uniform'}
#   accuracy : 0.7222222222222222
#   mcc : 0.82915619758885
#   sens : 28.57142857142857
#   spec : 100.0
# ============================
# 数据集划分 random_state：25时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.6944444444444444
#   mcc : 0.3624826753406541
#   sens : 57.14285714285714
#   spec : 77.27272727272727
# ============================
# 数据集划分 random_state：26时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'uniform'}
#   accuracy : 0.5833333333333334
#   mcc : 0.07857752591619217
#   sens : 41.66666666666667
#   spec : 66.66666666666666
# ============================
# 数据集划分 random_state：27时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.8055555555555556
#   mcc : 0.4486166927822573
#   sens : 87.5
#   spec : 78.57142857142857
# ============================
# 数据集划分 random_state：28时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 10, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.29316688507932437
#   sens : 30.76923076923077
#   spec : 86.95652173913044
# ============================
# 数据集划分 random_state：29时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.2987012987012987
#   sens : 57.14285714285714
#   spec : 72.72727272727273
# ============================
# 数据集划分 random_state：30时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'uniform'}
#   accuracy : 0.5277777777777778
#   mcc : -0.14704997960062352
#   sens : 14.285714285714285
#   spec : 77.27272727272727
# ============================
# 以上为IDR__16时，evaluation

# %%
# 评估结果
all_21_IDR_length_evaluate = []
# 设置超参数  
param_dict = {"n_neighbors": np.arange(1, 11), "weights":["uniform","distance"]}

# 21个IDR区域分别进行分类
for position in range(21):
    one_evaluate = []
    for r in range(31):
        one_random_state = []
        # 划分训练集和测试集
        Xtrain,Xtest,Ytrain,Ytest = train_test_split(all_21_IDR_disorder[position],input_lable,train_size=0.8,random_state = r)
        # build model
        model = KNeighborsClassifier()
        # 将模型加入超参数网格搜索和交叉验证     
        model = GridSearchCV(model, param_grid=param_dict, cv=5)
        # model train
        model = model.fit(Xtrain,Ytrain)
        # 最优的模型参数
        params = model.best_params_ 
        # 模型评估
        predict = model.predict(Xtest)
        cm = confusion_matrix(Ytest,predict)
        tn, tp, fn, fp = cm[0][0], cm[1][1], cm[1][0], cm[0][1]
        n = tp + fp + tn + fn
        accuracy = (tp + tn)/n 
        mcc = ((tp*tn) - (fp*fn))/np.sqrt((tp+fp)*(tn+fn)*(tp+fn)*(tn+fp))
        sens = tp/(tp + fn) * 100 if tp + fp != 0 else 0
        spec = tn/(tn + fp) * 100 if tn + fn != 0 else 0
        one_random_state.append(accuracy)
        one_random_state.append(mcc)
        one_random_state.append(sens)
        one_random_state.append(spec)
        one_evaluate.append(one_random_state)
        
        print("数据集划分 random_state：" + str(r)  + "时，")
        print("Evaluate：")
        print("最优的模型参数是：" + str(params))
        print("  accuracy : " + str(accuracy))
        print("  mcc : " + str(mcc))
        print("  sens : " + str(sens))
        print("  spec : " + str(spec)) 
        print("============================")
    
    all_21_IDR_length_evaluate.append(one_evaluate)
    print("以上为IDR__" + str(position + 1) + "时，evaluation")
    print("***********************************************************************")
# Out:
# 数据集划分 random_state：0时，
# Evaluate：
#   accuracy : 0.6111111111111112
#   mcc : 0.2586743945509748
#   sens : 20.0
#   spec : 90.47619047619048
# ============================
# 数据集划分 random_state：1时，
# Evaluate：
#   accuracy : 0.5
#   mcc : -0.04415107856883479
#   sens : 23.52941176470588
#   spec : 73.68421052631578
# ============================
# 数据集划分 random_state：2时，
# Evaluate：
#   accuracy : 0.4722222222222222
#   mcc : -0.01818181818181818
#   sens : 30.0
#   spec : 68.75
# ============================
# 数据集划分 random_state：3时，
# Evaluate：
#   accuracy : 0.5555555555555556
#   mcc : 0.07669649888473704
#   sens : 6.25
#   spec : 95.0
# ============================
# 数据集划分 random_state：4时，
# Evaluate：
#   accuracy : 0.6111111111111112
#   mcc : -0.13650002954034893
#   sens : 9.090909090909092
#   spec : 84.0
# ============================
# 数据集划分 random_state：5时，
# Evaluate：
#   accuracy : 0.5277777777777778
#   mcc : 0
# ============================
# 数据集划分 random_state：29时，
# Evaluate：
#   accuracy : 0.5833333333333334
#   mcc : -0.504524979109513
#   sens : 0.0
#   spec : 95.45454545454545
# ============================
# 数据集划分 random_state：30时，
# Evaluate：
#   accuracy : 0.5833333333333334
#   mcc : 0.05655768446177828
#   sens : 21.428571428571427
#   spec : 81.81818181818183
# ============================
# 以上为IDR__21时，evaluation
# ***********************************************************************

# %%
IDR_acc = [i[0] for i in all_evaluate[0]]
print(np.max(IDR_acc))
print(IDR_acc.index(np.max(IDR_acc)))
IDR_acc
# Out:
# 0.6944444444444444
# 16
# [0.6111111111111112,
#  0.5,
#  0.4722222222222222,
#  0.5555555555555556,
#  0.6111111111111112,
#  0.5277777777777778,
#  0.5833333333333334,
#  0.5555555555555556,
#  0.6111111111111112,
#  0.4722222222222222,
#  0.6111111111111112,
#  0.5,
#  0.3611111111111111,
#  0.5555555555555556,
#  0.5277777777777778,
#  0.5,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.5,
#  0.4722222222222222,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.4722222222222222,
#  0.5555555555555556,
#  0.5277777777777778,
#  0.5,
#  0.5555555555555556,
#  0.6388888888888888,
#  0.5,
#  0.6388888888888888,
#  0.4444444444444444]

# %%
for k in range(21):
    IDR_acc = [i[0] for i in all_evaluate[k]]

    print("IDR_" + str(k+1) + "__max_acc_all_evaluate：" + str(all_evaluate[k][IDR_acc.index(np.max(IDR_acc))])  
          + "  index_" +  str(IDR_acc.index(np.max(IDR_acc))))
# Out:
# IDR_1__max_acc_all_evaluate：[0.6944444444444444, 0.33803299298711376, 69.23076923076923, 69.56521739130434]  index_16
# IDR_2__max_acc_all_evaluate：[0.8055555555555556, 0.7147781553743946, 50.0, 95.83333333333334]  index_20
# IDR_3__max_acc_all_evaluate：[0.75, 0.38376546174370285, 70.0, 76.92307692307693]  index_17
# IDR_4__max_acc_all_evaluate：[0.7222222222222222, 0.34545454545454546, 54.54545454545454, 80.0]  index_22
# IDR_5__max_acc_all_evaluate：[0.8055555555555556, 0.7385489458759964, 57.14285714285714, 95.45454545454545]  index_25
# IDR_6__max_acc_all_evaluate：[0.8333333333333334, 0.9074852129730302, 25.0, 100.0]  index_27
# IDR_7__max_acc_all_evaluate：[0.7777777777777778, 0.35714285714285715, 50.0, 85.71428571428571]  index_27
# IDR_8__max_acc_all_evaluate：[0.7777777777777778, 0.35714285714285715, 50.0, 85.71428571428571]  index_7
# IDR_9__max_acc_all_evaluate：[0.8611111111111112, 0.6216495599043282, 62.5, 92.85714285714286]  index_27
# IDR_10__max_acc_all_evaluate：[0.7222222222222222, 0.23719978133155237, 50.0, 78.57142857142857]  index_7
# IDR_11__max_acc_all_evaluate：[0.8611111111111112, 0.5819143739626463, 75.0, 89.28571428571429]  index_27
# IDR_12__max_acc_all_evaluate：[0.7777777777777778, 0.3706246583305506, 62.5, 82.14285714285714]  index_27
# IDR_13__max_acc_all_evaluate：[0.8333333333333334, 0.5178571428571429, 62.5, 89.28571428571429]  index_27
# IDR_14__max_acc_all_evaluate：[0.8055555555555556, 0.6086973227418531, 71.42857142857143, 86.36363636363636]  index_13
# IDR_15__max_acc_all_evaluate：[0.75, 0.38498872152830715, 40.0, 88.46153846153845]  index_17
# IDR_16__max_acc_all_evaluate：[0.8055555555555556, 0.4486166927822573, 87.5, 78.57142857142857]  index_27
# IDR_17__max_acc_all_evaluate：[0.75, 0.40859257313228114, 30.0, 92.3076923076923]  index_17
# IDR_18__max_acc_all_evaluate：[0.8055555555555556, 0.6285393610547089, 58.333333333333336, 91.66666666666666]  index_15
# IDR_19__max_acc_all_evaluate：[0.6666666666666666, 0.03571428571428571, 25.0, 78.57142857142857]  index_7
# IDR_20__max_acc_all_evaluate：[0.7222222222222222, 0.4152252387021647, 73.33333333333333, 71.42857142857143]  index_0
# IDR_21__max_acc_all_evaluate：[0.7777777777777778, 0.3241018617760822, 12.5, 96.42857142857143]  index_7

# %%
all_R_H_IDR_disorder =[]
all_R_H_IDR_disorder.extend(disorder_R_H[0])
all_R_H_IDR_disorder.extend(disorder_R_H[1])

print(all_R_H_IDR_disorder[9])
# Out:
# [0.0087248204896847, 0.017681903438642583, 0.8818416258563166, 0.1020903351406256, 0.34141498644437107, 0.004856813466176343, 0.0025518597209486906, 0.0013681014970643, 0.008979560840608757, 0.0025181633850129307, 0.011107372171762865, 0.015542496391572, 0.011221860673685965, 0.0065629303322306005, 0.04181058678243837, 0.005707547563360925, 0.2298375570680946, 0.004028996452689113, 0.004458159940051129, 0.14946423069788858, 0.07328672856092448]

# %%
# 评估结果
all_IDR_avg_disorder_evaluate = []

# 将21个区域的平均disorder值一起作为特征
all_R_H_IDR_disorder =[]
all_R_H_IDR_disorder.extend(disorder_R_H[0])
all_R_H_IDR_disorder.extend(disorder_R_H[1])


# 设置超参数  
param_dict = {"n_neighbors": np.arange(1, 11), "weights":["uniform","distance"]}
for r in range(31):
    one_random_state = []
    # 划分训练集和测试集
    Xtrain,Xtest,Ytrain,Ytest = train_test_split(all_R_H_IDR_disorder,input_lable,train_size=0.8,random_state = r)
    # build model
    model = KNeighborsClassifier()
    # 将模型加入超参数网格搜索和交叉验证     
    model = GridSearchCV(model, param_grid=param_dict, cv=5)
    # model train
    model = model.fit(Xtrain,Ytrain)
    # 最优的模型参数
    params = model.best_params_ 
    # 模型评估
    predict = model.predict(Xtest)
    cm = confusion_matrix(Ytest,predict)
    tn, tp, fn, fp = cm[0][0], cm[1][1], cm[1][0], cm[0][1]
    n = tp + fp + tn + fn
    accuracy = (tp + tn)/n 
    mcc = ((tp*tn) - (fp*fn))/np.sqrt((tp+fp)*(tn+fn)*(tp+fn)*(tn+fp))
    sens = tp/(tp + fn) * 100 if tp + fp != 0 else 0
    spec = tn/(tn + fp) * 100 if tn + fn != 0 else 0
    
    one_random_state.append(accuracy)
    one_random_state.append(mcc)
    one_random_state.append(sens)
    one_random_state.append(spec)  
    all_IDR_avg_disorder_evaluate.append(one_random_state)
    
    print("数据集划分 random_state：" + str(r)  + "时，")
    print("Evaluate：")
    print("最优的模型参数是：" + str(params))
    print("  accuracy : " + str(accuracy))
    print("  mcc : " + str(mcc))
    print("  sens : " + str(sens))
    print("  spec : " + str(spec)) 
    print("============================")
# Out:
# 数据集划分 random_state：0时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'distance'}
#   accuracy : 0.75
#   mcc : 0.5345224838248488
#   sens : 60.0
#   spec : 85.71428571428571
# ============================
# 数据集划分 random_state：1时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'distance'}
#   accuracy : 0.6666666666666666
#   mcc : 0.42129071128957707
#   sens : 47.05882352941176
#   spec : 84.21052631578947
# ============================
# 数据集划分 random_state：2时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.6944444444444444
#   mcc : 0.6363636363636364
#   sens : 50.0
#   spec : 93.75
# ============================
# 数据集划分 random_state：3时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 5, 'weights': 'distance'}
#   accuracy : 0.6388888888888888
#   mcc : 0.27325202042558927
#   sens : 56.25
#   spec : 70.0
# ============================
# 数据集划分 random_state：4时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'distance'}
#   accuracy : 0.75
#   mcc : 0.40824829046386296
#   sens : 63.63636363636363
#   spec : 80.0
# ============================
# 数据集划分 random_state：5时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 4, 'weights': 'distance'}
#   accuracy : 0.6111111111111112
#   mcc : 0.3483693523249146
#   sens : 42.10526315789473
#   spec : 82.35294117647058
# ============================
# 数据集划分 random_state：6时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 4, 'weights': 'distance'}
#   accuracy : 0.6388888888888888
#   mcc : 0.24618298195866545
#   sens : 35.714285714285715
#   spec : 81.81818181818183
# ============================
# 数据集划分 random_state：7时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'distance'}
#   accuracy : 0.7222222222222222
#   mcc : 0.23719978133155237
#   sens : 50.0
#   spec : 78.57142857142857
# ============================
# 数据集划分 random_state：8时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'distance'}
#   accuracy : 0.7222222222222222
#   mcc : 0.5237849266164972
#   sens : 42.857142857142854
#   spec : 90.9090909090909
# ============================
# 数据集划分 random_state：9时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'distance'}
#   accuracy : 0.5
#   mcc : 0.03086817045916965
#   sens : 31.57894736842105
#   spec : 70.58823529411765
# ============================
# 数据集划分 random_state：10时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 5, 'weights': 'distance'}
#   accuracy : 0.7777777777777778
#   mcc : 0.6390096504226939
#   sens : 62.5
#   spec : 90.0
# ============================
# 数据集划分 random_state：11时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 10, 'weights': 'distance'}
#   accuracy : 0.7222222222222222
#   mcc : 0.5773502691896257
#   sens : 55.55555555555556
#   spec : 88.88888888888889
# ============================
# 数据集划分 random_state：12时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'distance'}
#   accuracy : 0.7222222222222222
#   mcc : 0.6622661785325219
#   sens : 47.05882352941176
#   spec : 94.73684210526315
# ============================
# 数据集划分 random_state：13时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 8, 'weights': 'distance'}
#   accuracy : 0.8055555555555556
#   mcc : 0.7385489458759964
#   sens : 57.14285714285714
#   spec : 95.45454545454545
# ============================
# 数据集划分 random_state：14时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.7222222222222222
#   mcc : 0.45151563399949557
#   sens : 60.0
#   spec : 80.95238095238095
# ============================
# 数据集划分 random_state：15时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 4, 'weights': 'distance'}
#   accuracy : 0.6944444444444444
#   mcc : 0.32489916153381576
#   sens : 33.33333333333333
#   spec : 87.5
# ============================
# 数据集划分 random_state：16时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.28210976821983985
#   sens : 61.53846153846154
#   spec : 69.56521739130434
# ============================
# 数据集划分 random_state：17时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.8888888888888888
#   mcc : 0.7968430154106838
#   sens : 70.0
#   spec : 96.15384615384616
# ============================
# 数据集划分 random_state：18时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.6111111111111112
#   mcc : 0.35816181173029066
#   sens : 50.0
#   spec : 78.57142857142857
# ============================
# 数据集划分 random_state：19时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 5, 'weights': 'uniform'}
#   accuracy : 0.6666666666666666
#   mcc : 0.27675549502120833
#   sens : 46.15384615384615
#   spec : 78.26086956521739
# ============================
# 数据集划分 random_state：20时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'distance'}
#   accuracy : 0.8333333333333334
#   mcc : 0.672538245981366
#   sens : 66.66666666666666
#   spec : 91.66666666666666
# ============================
# 数据集划分 random_state：21时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.6944444444444444
#   mcc : 0.539972451087909
#   sens : 50.0
#   spec : 88.88888888888889
# ============================
# 数据集划分 random_state：22时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'distance'}
#   accuracy : 0.75
#   mcc : 0.41576620649295015
#   sens : 54.54545454545454
#   spec : 84.0
# ============================
# 数据集划分 random_state：23时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 7, 'weights': 'distance'}
#   accuracy : 0.75
#   mcc : 0.5194344725754872
#   sens : 57.14285714285714
#   spec : 86.36363636363636
# ============================
# 数据集划分 random_state：24时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 1, 'weights': 'uniform'}
#   accuracy : 0.6388888888888888
#   mcc : 0.24618298195866545
#   sens : 35.714285714285715
#   spec : 81.81818181818183
# ============================
# 数据集划分 random_state：25时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 5, 'weights': 'distance'}
#   accuracy : 0.6944444444444444
#   mcc : 0.3798849127790877
#   sens : 50.0
#   spec : 81.81818181818183
# ============================
# 数据集划分 random_state：26时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'distance'}
#   accuracy : 0.75
#   mcc : 0.4453617714151233
#   sens : 58.333333333333336
#   spec : 83.33333333333334
# ============================
# 数据集划分 random_state：27时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 6, 'weights': 'distance'}
#   accuracy : 0.7777777777777778
#   mcc : 0.3450327796711771
#   sens : 37.5
#   spec : 89.28571428571429
# ============================
# 数据集划分 random_state：28时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 4, 'weights': 'distance'}
#   accuracy : 0.6111111111111112
#   mcc : 0.1402733330929412
#   sens : 38.46153846153847
#   spec : 73.91304347826086
# ============================
# 数据集划分 random_state：29时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 5, 'weights': 'distance'}
#   accuracy : 0.6111111111111112
#   mcc : 0.18181818181818182
#   sens : 50.0
#   spec : 68.18181818181817
# ============================
# 数据集划分 random_state：30时，
# Evaluate：
# 最优的模型参数是：{'n_neighbors': 9, 'weights': 'distance'}
#   accuracy : 0.75
#   mcc : 0.5194344725754872
#   sens : 57.14285714285714
#   spec : 86.36363636363636
# ============================

# %%
np.max([i[0] for i in all_IDR_avg_disorder_evaluate])
# Out:
# 0.8888888888888888
