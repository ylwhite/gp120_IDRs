# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
import seaborn as sns
import pysam as sam
import pickle

import warnings

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
disorder_R_H = pickle.load(open('/home/dldx/R-H/code/classification/ML/data/disorder/avg_R-H_all_dsiorder.pkl','rb'))

# %%
# α1-β2    -----------   IDR1
sns.set_context({'figure.figsize':[7, 4]})
x_1 = np.array([i[0] for i in disorder_R_H[0]])
x_2 = np.array([i[0] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)
plt.title("IDR1",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=12)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR1_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β2-βa   -----------   IDR2
plt.figure(figsize=(7, 4))
x_1 = np.array([i[1] for i in disorder_R_H[0]])
x_2 = np.array([i[1] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR2",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR2_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# βa-βb    -----------   IDR3
plt.figure(figsize=(7, 4))
x_1 = np.array([i[2] for i in disorder_R_H[0]])
x_2 = np.array([i[2] for i in disorder_R_H[1]])

plt.xticks([-0.9,-0.7,-0.5,-0.3,-0.1])
plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR3",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR3_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# βb-βc   -----------   IDR4
plt.figure(figsize=(7, 4))
x_1 = np.array([i[3] for i in disorder_R_H[0]])
x_2 = np.array([i[3] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR4",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR4_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# βc-βd   -----------   IDR5
plt.figure(figsize=(7, 4))
x_1 = np.array([i[4] for i in disorder_R_H[0]])
x_2 = np.array([i[4] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR5",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR5_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# βd-β3   -----------   IDR6
plt.figure(figsize=(7, 4))
x_1 = np.array([i[5] for i in disorder_R_H[0]])
x_2 = np.array([i[5] for i in disorder_R_H[1]])

plt.xticks([-6.00,-5.50,-5.00,-4.50,-4.00])
plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)


plt.title("IDR6",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR6_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β3-β4   -----------   IDR7
plt.figure(figsize=(7, 4))
x_1 = np.array([i[6] for i in disorder_R_H[0]])
x_2 = np.array([i[6] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR7",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR7_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β4-β5   -----------   IDR8
plt.figure(figsize=(7, 4))
x_1 = np.array([i[7] for i in disorder_R_H[0]])
x_2 = np.array([i[7] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR8",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR8_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β5-β6   -----------   IDR9
plt.figure(figsize=(7, 4))
x_1 = np.array([i[8] for i in disorder_R_H[0]])
x_2 = np.array([i[8] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR9",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR9_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β7-β9   -----------   IDR10
plt.figure(figsize=(7, 4))
x_1 = np.array([i[9] for i in disorder_R_H[0]])
x_2 = np.array([i[9] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR10",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR10_disorder_KDE.jpg",dpi=900)
plt.show()
# Out:
# <ipython-input-14-a1b7374df73d>:9: RuntimeWarning: divide by zero encountered in log
#   sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)

# %%
# β9-β10   -----------   IDR11
plt.figure(figsize=(7, 4))
x_1 = np.array([i[10] for i in disorder_R_H[0]])
x_2 = np.array([i[10] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR11",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR11_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β10-β11   -----------   IDR12
plt.figure(figsize=(7, 4))
x_1 = np.array([i[11] for i in disorder_R_H[0]])
x_2 = np.array([i[11] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR12",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR12_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β12-β13   -----------   IDR13
plt.figure(figsize=(7, 4))
x_1 = np.array([i[12] for i in disorder_R_H[0]])
x_2 = np.array([i[12] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR13",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR13_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# α2-β14   -----------   IDR14
plt.figure(figsize=(7, 4))
x_1 = np.array([i[13] for i in disorder_R_H[0]])
x_2 = np.array([i[13] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR14",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder",weight='bold',fontsize=8)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR14_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β14-α3   -----------   IDR15
plt.figure(figsize=(7, 4))
x_1 = np.array([i[14] for i in disorder_R_H[0]])
x_2 = np.array([i[14] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR15",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder Score",weight='bold',fontsize=10)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR15_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β17-α4   -----------   IDR16
plt.figure(figsize=(7, 4))
x_1 = np.array([i[15] for i in disorder_R_H[0]])
x_2 = np.array([i[15] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR16",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder Score",weight='bold',fontsize=10)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR16_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# α4-β19  -----------   IDR17
plt.figure(figsize=(7, 4))
x_1 = np.array([i[16] for i in disorder_R_H[0]])
x_2 = np.array([i[16] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR17",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder Score",weight='bold',fontsize=10)
# plt.ylabel("Probability",weight='bold',fontsize=8)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR17_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β20-β21  -----------   IDR18
plt.figure(figsize=(7, 4))
x_1 = np.array([i[17] for i in disorder_R_H[0]])
x_2 = np.array([i[17] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR18",weight='bold',fontsize=12,loc ='left')
# plt.xlabel("Disorder Score",weight='bold',fontsize=10)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR18_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β21-β22  -----------   IDR19
plt.figure(figsize=(7, 4))
x_1 = np.array([i[18] for i in disorder_R_H[0]])
x_2 = np.array([i[18] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR19",weight='bold',fontsize=12,loc ='left')
plt.xlabel("Disorder Score",weight='bold',fontsize=14)
plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR19_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β23-β24  -----------   IDR20
plt.figure(figsize=(7, 4))
x_1 = np.array([i[19] for i in disorder_R_H[0]])
x_2 = np.array([i[19] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR20",weight='bold',fontsize=12,loc ='left')
plt.xlabel("Disorder Score",weight='bold',fontsize=14)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR20_disorder_KDE.jpg",dpi=900)
plt.show()

# %%
# β24-α5  -----------   IDR21
plt.figure(figsize=(7, 4))
x_1 = np.array([i[20] for i in disorder_R_H[0]])
x_2 = np.array([i[20] for i in disorder_R_H[1]])

plt.ylim(0.00,0.33)
plt.yticks([0.00,0.08,0.16,0.24,0.32])
sns.histplot(np.log(x_1), kde=True, stat='probability', color='red', bins=20)
sns.histplot(np.log(x_2), kde=True, stat='probability', color='blue', bins=20)
plt.legend(["Sensitive","Resistant"],loc="upper right",ncol=2)
plt.xticks(weight='bold',fontsize=12)
plt.yticks(weight='bold',fontsize=12)

plt.title("IDR21",weight='bold',fontsize=12,loc ='left')
plt.xlabel("Disorder Score",weight='bold',fontsize=14)
# plt.ylabel("Probability",weight='bold',fontsize=14)
plt.savefig("/home/dldx/R-H/code/classification/ML/plot/fig3/IDR21_disorder_KDE.jpg",dpi=900)
plt.show()
