# %%
import biolib

# %%
nsp3 = biolib.load('DTU/NetSurfP_3')
nsp3_results = nsp3.cli(args='-i /www/yang/csv/MSA_before/1.fa')
nsp3_results.save_files("/www/yang/csv/Tier_1_out")
# Out:
# 2023-05-19 11:54:58,391 | INFO : Loaded project DTU/NetSurfP-3:0.0.2
# 2023-05-19 11:55:00,996 | INFO : Job "b8393aac-46aa-4e3b-989d-e577d7e75f59" is starting...
# 2023-05-19 11:55:12,602 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:55:23,979 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:55:37,351 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:55:48,670 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:56:00,047 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:56:11,391 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:56:22,909 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:56:36,009 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:56:47,349 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 11:56:58,696 | INFO : Cloud: The job has been queued. Please wait...
# ...

# %%
nsp3 = biolib.load('DTU/NetSurfP_3')
nsp3_results = nsp3.cli(args='-i /www/yang/csv/MSA_before/3.fa')
nsp3_results.save_files("/www/yang/csv/Tier_3_out")
# Out:
# 2023-05-19 12:46:49,683 | INFO : Loaded project DTU/NetSurfP-3:0.0.2
# 2023-05-19 12:46:53,330 | INFO : Job "9684834a-dd03-49f7-a11b-eff397267a7e" is starting...
# 2023-05-19 12:47:10,012 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:47:21,607 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:47:33,644 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:47:46,281 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:47:57,591 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:48:09,862 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:48:21,941 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:48:33,333 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:48:47,259 | INFO : Cloud: The job has been queued. Please wait...
# 2023-05-19 12:48:58,574 | INFO : Cloud: The job has been queued. Please wait...
# ...
